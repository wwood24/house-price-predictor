# %% [markdown]
# # Review Preprocessing Pipeline
#
# prior to adding the preprocessor to mlflow tracking server with code
# want to see how the data looks to make sure the transform worked

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import os

# %%
pd.set_option('display.max_columns',None)

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
DATA_DIR = Path(os.getenv('DATA_DIR','/app/data'))

# %%
DATA_DIR
# Out:
# PosixPath('/home/ExraDrive/house_prices/data')

# %% [markdown]
# # Load Data

# %%
clean_df = pd.read_pickle(DATA_DIR/'house_price_processed.pkl')

# %%
clean_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_data=pd.read_pickle(DATA_DIR/'train_data.pkl')

# %%
train_data.head()
# Out:
#       OverallQual  OverallCond  age_at_sale  age_of_house_squared  \
# 254             5            6           53                  2809
# 1066            6            7           16                   256
# 638             5            7           98                  9604
# 799             5            7           70                  4900
# 380             5            6           86                  7396
#
#       house_have_remodel  GrLivArea  TotalBsmtSF  total_sf  \
# 254                    0       1314         1314      2628
# 1066                   1       1571          799      2370
# 638                    1        796          796      1592
# 799                    1       1768          731      2499
# 380                    1       1691         1026      2717
#
#       ratio_finished_bsmt  basement_ratio  total_full_baths  total_half_baths  \
# 254              0.701141        0.499810                 2                 0
# ...

# %%
train_y = pd.read_pickle(DATA_DIR/'train_y_data.pkl')

# %%
train_y
# Out:
# 254     145000
# 1066    178000
# 638      85000
# 799     175000
# 380     127000
#          ...
# 1095    176432
# 1130    135000
# 1294    115000
# 860     189950
# 1126    174000
# Name: SalePrice, Length: 1168, dtype: int64

# %%
test_x = pd.read_pickle(DATA_DIR/'test_data.pkl')

# %%
test_x.head()
# Out:
#       OverallQual  OverallCond  age_at_sale  age_of_house_squared  \
# 892             6            8           43                  1849
# 1105            8            5           16                   256
# 413             5            6           83                  6889
# 522             6            7           59                  3481
# 1036            9            5            2                     4
#
#       house_have_remodel  GrLivArea  TotalBsmtSF  total_sf  \
# 892                    1       1068         1059      2127
# 1105                   1       2622         1463      4085
# 413                    1       1028         1008      2036
# 522                    1       1664         1004      2668
# 1036                   1       1620         1620      3240
#
#       ratio_finished_bsmt  basement_ratio  total_full_baths  total_half_baths  \
# 892              0.625472        0.497650                 1                 1
# ...
